# %% [markdown]
# # 06. Index Sensitivity, Robustness & Criterion Validity
# **Research Objective**: Test alternative PEI weighting specifications (role-balanced vs. equal vs. non-substitution) and assess criterion-related validity against platform recommendation and prospective service offering.

# %%
import pandas as pd
from src.index import evaluate_index_properties
from src.config import PROC_INDEX_CSV

idf = pd.read_csv(PROC_INDEX_CSV)
summary_df, pearson_corr, spearman_corr, validity_df = evaluate_index_properties(idf)

print("Correlation Between Alternative Index Formulations:")
print(pearson_corr.round(3))

print("
Criterion Validity Results:")
print(validity_df)

# %% [markdown]
# ### Methodological Assessment
# - High inter-formulation correlations ($r > 0.90$) confirm that respondent rankings are invariant to reasonable variations in component weighting schemes.
# - Statistically significant positive correlations with platform recommendation advocacy ($p < 0.001$) and future offering intention ($p < 0.001$) provide empirical evidence of criterion-related validity.
