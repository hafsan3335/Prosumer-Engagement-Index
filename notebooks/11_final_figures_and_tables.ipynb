# %% [markdown]
# # 11. Publication-Ready Scientific Figures and Tables
# **Research Objective**: Compile and export all high-resolution figures and APA/academic statistical tables for research dissemination.

# %%
import os
from src.visualization import run_visualization_pipeline
from src.config import FIGURES_DIR, TABLES_DIR

# Execute figure export
run_visualization_pipeline()
print("Generated Figures in:", FIGURES_DIR)
for f in os.listdir(FIGURES_DIR):
    print(" -", f)

# %% [markdown]
# ### Dissemination Package
# - All 13 scientific figures and 8 standardized statistical tables successfully generated and archived.
